# %%
import matplotlib.pyplot as plt
import numpy

def show(img):
    plt.figure(figsize=(20, 20), dpi=50)
    plt.imshow(img, cmap='gray')

event = numpy.load('/home/runqiu/datasets/debug/0_ev.npy')
show(event[0,0,:,:,0,8])

# %%
gt = numpy.load('/home/runqiu/datasets/debug/0_gt.npy')
show(gt[0])

# %%
pred = numpy.load('/home/runqiu/datasets/debug/0.npy')
show(pred[0])

# %%
import cv2
blended = cv2.addWeighted(pred[0], 0.5, img2, beta, 0.0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 blended = cv2.addWeighted(img1, alpha, img2, beta, 0.0)
#
# NameError: name 'cv2' is not defined
